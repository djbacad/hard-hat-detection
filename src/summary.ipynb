# %% [markdown]
# ### Metrics Comparison: Default vs Tuned

# %%
from PIL import Image
from IPython.display import display
import pandas as pd

# %% [markdown]
# *When the hyperparameters were tuned, the objective was to find the set that would maximize the mAP50.*

# %% [markdown]
# #### Training Metrics - Default

# %%
image_path = "../ultralytics/runs/detect/yolov8n_custom_default/results.png"
image = Image.open(image_path)
image = image.resize((1000,500))
display(image)
# Out:
# <PIL.Image.Image image mode=RGBA size=1000x500>

# %%
pd.read_csv("../ultralytics/runs/detect/yolov8n_custom_default/results.csv").tail(1)
# Out:
#                      epoch           train/box_loss           train/cls_loss
# 9                        9                   1.1372                  0.57213  \
#
#             train/dfl_loss     metrics/precision(B)        metrics/recall(B)
# 9                   1.0796                  0.95666                  0.93083  \
#
#           metrics/mAP50(B)      metrics/mAP50-95(B)             val/box_loss
# 9                  0.97606                  0.67255                   1.1447  \
#
#               val/cls_loss             val/dfl_loss                   lr/pg0
# 9                  0.50285                   1.1009                  0.00208  \
#
#                     lr/pg1                   lr/pg2
# 9                  0.00208                  0.00208

# %% [markdown]
# #### Training Metrics - Tuned

# %%
image_path = "../ultralytics/runs/detect/train211/results.png"
image = Image.open(image_path)
image = image.resize((1000,500))
display(image)
# Out:
# <PIL.Image.Image image mode=RGBA size=1000x500>

# %%
pd.read_csv("../ultralytics/runs/detect/train211/results.csv").tail(1)
# Out:
#                      epoch           train/box_loss           train/cls_loss
# 9                        9                   1.0995                  0.57984  \
#
#             train/dfl_loss     metrics/precision(B)        metrics/recall(B)
# 9                   1.0807                  0.95736                  0.93969  \
#
#           metrics/mAP50(B)      metrics/mAP50-95(B)             val/box_loss
# 9                  0.98035                  0.66545                   1.1471  \
#
#               val/cls_loss             val/dfl_loss                   lr/pg0
# 9                  0.52083                   1.1151                 0.000875  \
#
#                     lr/pg1                   lr/pg2
# 9                 0.000875                 0.000875

# %% [markdown]
# *The precision, recall, and mAP50 are all better with the hyperparameter-tuned model. Expanding the search space for the tuning process will definitely return better results but will also be computationally expensive.*
